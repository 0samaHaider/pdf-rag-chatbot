# %% [markdown]
# ### Install dependencies

# %%
# !pip install sentence-transformers chromadb transformers torch PyPDF2
# Out:
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sentence-transformers in .\Osama Haider\anaconda3\Lib\site-packages (5.2.2)
# Requirement already satisfied: chromadb in .\Osama Haider\anaconda3\Lib\site-packages (1.4.1)
# Requirement already satisfied: transformers in .\Osama Haider\anaconda3\Lib\site-packages (5.0.0)
# Requirement already satisfied: torch in .\Osama Haider\anaconda3\Lib\site-packages (2.10.0)
# Requirement already satisfied: PyPDF2 in .\Osama Haider\anaconda3\Lib\site-packages (3.0.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in .\Osama Haider\anaconda3\Lib\site-packages (from sentence-transformers) (1.3.5)
# Requirement already satisfied: numpy in .\Osama Haider\anaconda3\Lib\site-packages (from sentence-transformers) (2.1.3)
# Requirement already satisfied: scikit-learn in .\Osama Haider\anaconda3\Lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in .\Osama Haider\anaconda3\Lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in .\Osama Haider\anaconda3\Lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in .\Osama Haider\anaconda3\Lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: filelock in .\Osama Haider\anaconda3\Lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: packaging>=20.0 in .\Osama Haider\anaconda3\Lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in .\Osama Haider\anaconda3\Lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in .\Osama Haider\anaconda3\Lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in .\Osama Haider\anaconda3\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in .\Osama Haider\anaconda3\Lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in .\Osama Haider\anaconda3\Lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in .\Osama Haider\anaconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in .\Osama Haider\anaconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\Osama Haider\anaconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: shellingham in .\Osama Haider\anaconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: anyio in .\Osama Haider\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.7.0)
# Requirement already satisfied: certifi in .\Osama Haider\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in .\Osama Haider\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in .\Osama Haider\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in .\Osama Haider\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: build>=1.0.3 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pydantic>=1.9 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (2.10.3)
# Requirement already satisfied: pybase64>=1.4.1 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in .\Osama Haider\anaconda3\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.40.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: pypika>=0.48.9 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (0.50.0)
# Requirement already satisfied: overrides>=7.3.1 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (3.11.6)
# Requirement already satisfied: rich>=10.11.0 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in .\Osama Haider\anaconda3\Lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: requests<3.0,>=2.7 in .\Osama Haider\anaconda3\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.3)
# Requirement already satisfied: six>=1.5 in .\Osama Haider\anaconda3\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in .\Osama Haider\anaconda3\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in .\Osama Haider\anaconda3\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in .\Osama Haider\anaconda3\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\Osama Haider\anaconda3\Lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\Osama Haider\anaconda3\Lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.5.0)
# Requirement already satisfied: sympy>=1.13.3 in .\Osama Haider\anaconda3\Lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in .\Osama Haider\anaconda3\Lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in .\Osama Haider\anaconda3\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in .\Osama Haider\anaconda3\Lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: pyproject_hooks in .\Osama Haider\anaconda3\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in .\Osama Haider\anaconda3\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in .\Osama Haider\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\Osama Haider\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in .\Osama Haider\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in .\Osama Haider\anaconda3\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in .\Osama Haider\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in .\Osama Haider\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in .\Osama Haider\anaconda3\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in .\Osama Haider\anaconda3\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in .\Osama Haider\anaconda3\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in .\Osama Haider\anaconda3\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in .\Osama Haider\anaconda3\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in .\Osama Haider\anaconda3\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in .\Osama Haider\anaconda3\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in .\Osama Haider\anaconda3\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in .\Osama Haider\anaconda3\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in .\Osama Haider\anaconda3\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in .\Osama Haider\anaconda3\Lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in .\Osama Haider\anaconda3\Lib\site-packages (from pydantic>=1.9->chromadb) (2.27.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\Osama Haider\anaconda3\Lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\Osama Haider\anaconda3\Lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in .\Osama Haider\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\Osama Haider\anaconda3\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in .\Osama Haider\anaconda3\Lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: httptools>=0.6.3 in .\Osama Haider\anaconda3\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in .\Osama Haider\anaconda3\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in .\Osama Haider\anaconda3\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in .\Osama Haider\anaconda3\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: sniffio>=1.1 in .\Osama Haider\anaconda3\Lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in .\Osama Haider\anaconda3\Lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in .\Osama Haider\anaconda3\Lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in .\Osama Haider\anaconda3\Lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in .\Osama Haider\anaconda3\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.2.0 in .\Osama Haider\anaconda3\Lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in .\Osama Haider\anaconda3\Lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)

# %% [markdown]
# ### Imports

# %%
from sentence_transformers import SentenceTransformer
from transformers import GPT2Tokenizer, GPT2LMHeadModel, T5Tokenizer, T5ForConditionalGeneration
from PyPDF2 import PdfReader
import chromadb
import uuid
import os

# %% [markdown]
# ### Initialize models

# %%
# BERT embeddings model
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# GPT2 for answer generation
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")

print("Models loaded successfully")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Models loaded successfully

# %% [markdown]
# ### Initialize ChromaDB (in-memory)

# %%
client = chromadb.Client()
collection = client.create_collection(name="rag_docs_db")

print("ChromaDB collection created")
# Out:
# ChromaDB collection created

# %% [markdown]
# ### Load and read document (PDF or TXT)

# %%
FILE_PATH = r"C:\Users\Osama Haider\Downloads\Scholarship Recipients Questions.pdf"  # or sample.txt

def load_document(file_path):
    texts = []

    if file_path.endswith(".pdf"):
        reader = PdfReader(file_path)
        for page in reader.pages:
            text = page.extract_text()
            if text:
                texts.append(text)

    elif file_path.endswith(".txt"):
        with open(file_path, "r", encoding="utf-8") as f:
            texts.append(f.read())

    return texts

documents = load_document(FILE_PATH)
print(f"Loaded {len(documents)} document(s)")
# Out:
# Loaded 4 document(s)

# %% [markdown]
# ### Chunk the document

# %%
def chunk_text(text, chunk_size=500, overlap=100):
    chunks = []
    start = 0

    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start += chunk_size - overlap

    return chunks

all_chunks = []
for doc in documents:
    all_chunks.extend(chunk_text(doc))

print(f"Total chunks created: {len(all_chunks)}")
# Out:
# Total chunks created: 17

# %% [markdown]
# ### Embed and store in ChromaDB

# %%
for chunk in all_chunks:
    collection.add(
        ids=[str(uuid.uuid4())],
        documents=[chunk],
        embeddings=[embedding_model.encode(chunk).tolist()]
    )

print("All chunks embedded and stored")
# Out:
# All chunks embedded and stored

# %% [markdown]
# ### Retrieval function (RAG step)

# %%
def retrieve_docs(query, top_k=3):
    query_embedding = embedding_model.encode(query).tolist()
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=top_k
    )
    return results["documents"][0]

# %% [markdown]
# ### Prompt builder

# %%
def build_prompt(query, retrieved_chunks):
    context = "\n\n".join(retrieved_chunks)

    return f"""
Answer the question using ONLY the context below.
If the answer is not in the context, say:
"I cannot find this information in the provided documents."

Context:
{context}

Question:
{query}

Answer:
""".strip()

# %% [markdown]
# ### Answer generation (GPT-2)

# %%
def generate_answer(query, retrieved_chunks, max_new_tokens=150):
    prompt = build_prompt(query, retrieved_chunks)

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=1024
    )

    outputs = model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=max_new_tokens
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %% [markdown]
# ### Chat with your document

# %%
def is_valid_question(query):
    return len(query.split()) > 2

while True:
    query = input("\nAsk a question (or type 'exit'): ")

    if query.lower() == "exit":
        break

    if not is_valid_question(query):
        print("Please ask a meaningful question about the document.")
        continue

    retrieved_chunks = retrieve_docs(query)
    answer = generate_answer(query, retrieved_chunks)

    print("\nAnswer:")
    print(answer)
# Out:
# Ask a question (or type 'exit'):  Which university is he studying at?
# Answer:
# University of Milano -Bicocca
# Ask a question (or type 'exit'):  Which technologies has he mainly worked with?
# Answer:
# backend development
# Ask a question (or type 'exit'):  What was his CGPA in the bachelor’s degree?
# Answer:
# 3.57/4
